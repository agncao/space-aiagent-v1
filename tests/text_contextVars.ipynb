# %%
from contextvars import ContextVar

var = ContextVar('var')
token  =var.set(1)
print(var.get())
var.set(2)
print(var.get())
var.reset( token)
print(var.get())
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[3], line 9
#       5 print(var.get())
#       6 var.set(2)
#       7 print(var.get())
#       8 var.reset( token)
# ----> 9 print(var.get())
#
# LookupError: <ContextVar name='var' at 0x1056c1210>
